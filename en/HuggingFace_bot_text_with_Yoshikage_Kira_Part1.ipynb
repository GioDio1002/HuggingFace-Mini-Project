# %% [markdown]
# # PreFace
# Inspired from [Bot detection machine learning project]() of Master of Data Science in HSE on coursera, this notebook will explore *a series of NLP analysis with huggingface*, e.g bot text generation, sentiment analysis. Finally, to predict whether the text is a bot text or not. For further studies, we may try the bot detection in other languages and other NLP toolkits as well.

# %% [markdown]
# # References:
# *   [GPT-2-HuggingFace](https://huggingface.co/gpt2)
# * [bert-base-multilingual-uncased-sentiment](https://huggingface.co/nlptown/bert-base-multilingual-uncased-sentiment)
# * [pysentimiento: A Python toolkit for Sentiment Analysis and Social NLP tasks](https://github.com/pysentimiento/pysentimiento)
# * [Word Embeddings— Fun with Word2Vec and Game of Thrones](https://medium.com/@khulasaandh/word-embeddings-fun-with-word2vec-and-game-of-thrones-ea4c24fcf1b8)
# * [GloVe-tutorial](https://github.com/EvolvedSquid/tutorials/blob/master/using-pretrained-glove-vectors/GloVe-tutorial.ipynb)

# %%
# !pip install transformers pysentimiento
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.6.1)
# Requirement already satisfied: pysentimiento in /usr/local/lib/python3.7/dist-packages (0.2.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers) (20.9)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers) (0.0.45)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.41.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers) (4.5.0)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.10.3)
# Requirement already satisfied: huggingface-hub==0.0.8 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.0.8)
# Requirement already satisfied: emoji in /usr/local/lib/python3.7/dist-packages (from pysentimiento) (1.2.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.4.1)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.7.4.3)

# %%
from transformers import pipeline, set_seed, AutoTokenizer, AutoModelForSequenceClassification
from pysentimiento import SentimentAnalyzer,EmotionAnalyzer
import requests
from bs4 import BeautifulSoup
import bleach
import re
import pandas as pd
from tqdm import tqdm_notebook as tqdm
import seaborn as sns
import matplotlib.pyplot as plt
from gensim.models import Word2Vec
from gensim.utils import simple_preprocess
from nltk.tokenize import sent_tokenize
from nltk.tokenize import WordPunctTokenizer
from nltk.stem import WordNetLemmatizer 
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import nltk

# %% [markdown]
#  # Data Collection
#  ![image.png](data:image/png;base64,...)

# %% [markdown]
# A simple web-scraping will be used for the Yoshikage Kira's speech.

# %%
#Webscrape the Youshikage Kira's notorious self-introduction in English from jojo.fandom.com
response = requests.get(url='https://jojo.fandom.com/f/p/4400000000000073990')
response.encoding = response.apparent_encoding
soup = BeautifulSoup(response.content, 'html.parser')
para = soup.find_all('p')  #Get the paragraph element
para
# Out:
# [<p>My name is Yoshikage Kira. I'm 33 years old. My house is in the northeast section of Morioh, where all the villas are, and I am not married. I work as an employee for the Kame Yu department stores, and I get home every day by 8 PM at the latest. I don't smoke, but I occasionally drink. I'm in bed by 11 PM, and make sure I get eight hours of sleep, no matter what. After having a glass of warm milk and doing about twenty minutes of stretches before going to bed, I usually have no problems sleeping until morning. Just like a baby, I wake up without any fatigue or stress in the morning. I was told there were no issues at my last check-up. I'm trying to explain that I'm a person who wishes to live a very quiet life. I take care not to trouble myself with any enemies, like winning and losing, that would cause me to lose sleep at night. That is how I deal with society, and I know that is what brings me happiness. Although, if I were to fight I wouldn't lose to anyone.</p>,
#  <p>...nvm-</p>,
#  <p>Haha very funny &gt;&gt;:(</p>,
#  <p>Yes, very nice. VERY nice.</p>,
#  <p>My name is Yoshikage Kira. I'm 33 years old. My house is in the northeast section of Morioh, where all the villas are, and I am not married. I work as an employee for the Kame Yu department stores, and I get home every day by 8 PM at the latest. I don't smoke, but I occasionally drink. I'm in bed by 11 PM, and make sure I get eight hours of sleep, no matter what. After having a glass of warm milk and doing about twenty minutes of stretches before going to bed, I usually have no problems sleeping until morning. Just like a baby, I wake up without any fatigue or stress in the morning. I was told there were no issues at my last check-up. I'm trying to explain that I'm a person who wishes to live a very quiet life. I take care not to trouble myself with any enemies, like winning and losing, that would cause me to lose sleep at night. That is how I deal with society, and I know that is what brings me happiness. Although, if I were to fight I wouldn't lose to anyone.</p>,
#  <p>Necroposting.</p>,
#  <p>Been 4 months lol</p>,
#  <p>1/3 of a year</p>,
#  <p>Thank you</p>,
#  <p>NECROPOSTING</p>,
#  <p><br/></p>,
#  <p><a href="/f/u/44196195">@Legendary Super Saiyan Fennekin</a> </p>,
#  <p>Ah was that where the ping was from</p>]

# %%
para1 = []
for p in para:
  para1.append(str(p))
for p in para1: #The first line is our target passage so only break is used.
    clean = bleach.clean(p,tags=[],strip=True) #Remove tags with bleach
    break
clean
# Out:
# "My name is Yoshikage Kira. I'm 33 years old. My house is in the northeast section of Morioh, where all the villas are, and I am not married. I work as an employee for the Kame Yu department stores, and I get home every day by 8 PM at the latest. I don't smoke, but I occasionally drink. I'm in bed by 11 PM, and make sure I get eight hours of sleep, no matter what. After having a glass of warm milk and doing about twenty minutes of stretches before going to bed, I usually have no problems sleeping until morning. Just like a baby, I wake up without any fatigue or stress in the morning. I was told there were no issues at my last check-up. I'm trying to explain that I'm a person who wishes to live a very quiet life. I take care not to trouble myself with any enemies, like winning and losing, that would cause me to lose sleep at night. That is how I deal with society, and I know that is what brings me happiness. Although, if I were to fight I wouldn't lose to anyone."

# %%
#Count the number of sentences
print(len(clean.split('.')))
clean.split('.')
# Out:
# 14
# ['My name is Yoshikage Kira',
#  " I'm 33 years old",
#  ' My house is in the northeast section of Morioh, where all the villas are, and I am not married',
#  ' I work as an employee for the Kame Yu department stores, and I get home every day by 8 PM at the latest',
#  " I don't smoke, but I occasionally drink",
#  " I'm in bed by 11 PM, and make sure I get eight hours of sleep, no matter what",
#  ' After having a glass of warm milk and doing about twenty minutes of stretches before going to bed, I usually have no problems sleeping until morning',
#  ' Just like a baby, I wake up without any fatigue or stress in the morning',
#  ' I was told there were no issues at my last check-up',
#  " I'm trying to explain that I'm a person who wishes to live a very quiet life",
#  ' I take care not to trouble myself with any enemies, like winning and losing, that would cause me to lose sleep at night',
#  ' That is how I deal with society, and I know that is what brings me happiness',
#  " Although, if I were to fight I wouldn't lose to anyone",
#  '']

# %%
n = len(clean)
generator = pipeline('text-generation', model='gpt2') #text generator, aka gpt-2, pipline initiation
set_seed(42)

# %% [markdown]
# ## Bot Text Generation

# %%
 #Bot Text Generation with GPT2
 bot_kira = generator("My name is Yoshikage Kira. I'm 33 years old.", max_length=n, num_return_sequences=1) #
 bot_kira
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'My name is Yoshikage Kira. I\'m 33 years old. I have not played for my entire life. I don\'t think I am a professional ballplayer, but at the time it was obvious. Now I am starting to ask myself, what am I supposed to do? I try to avoid confrontation. When I play the game, I always say, \'Ouch.\' I get no help from people and I get no support from people who are very well-known people. At least after a while there will be a place called this place and I will always be the one who gets to understand me. At that moment, I go to the other place and I say to myself, \'This person has made a fool of myself.\' But I feel that my body just isn\'t ready for that kind of situation. I go to a place near my house and look around my house and I see all kinds of things that don\'t make sense. Those things aren\'t why I go to this place. Why I don\'t go to others places as I\'m very concerned about my life. Why do people think I\'m so good, that I\'m useless? Why do you think I\'m so lucky? I want to prove that I\'m still great so that they wouldn\'t have made a fool of themselves. But at the end of the day, this is just a way to make a name for myself. I want everyone to respect me for what I do." The first person who told me about his story was a member of the Shinigami Family for Girls, the idol group which played and trained her. "I remember a time when I played the first day of school," she said, "and everyone was playing at the same time. On the first day, everyone were at the same spot. As soon as you started playing with me...the idol group started a chant and I could hear about their chanting and I took it to be as well. So I was like, \'We get to watch you play in the morning\'. So we did and everything went well." Yoshikage Kira\'s "liked, disliked" conversation with the other girls who were nearby started a day long conversation that lasted for five minutes, and I have no recollection of the conversation. My understanding of what was going on was not quite right. On the day that I started the first day of school, I thought about how great that I had done so far. This would be the first time my parents would do something like this again. You know, even before my parents, my grandfather passed away and I was just very old. I don\'t remember feeling any different for a long time. In the end I have no idea what the future holds for me, for my life, especially the future part of it. I don\'t get to show my affection to anybody, especially the children, but I love them. I want them to have one thing in common with me, which is that I am my own person. I don\'t care more about the way the world is with me. I want to be loved and to be respected and to be respected is what I have done in life. "I wish I would never tell a mother to be ashamed," Yoshikage Kira said. "All of a sudden I have an older brother, and the younger brother said that to me about me: \'I was in the club when I was 15 years old.\' She said to me, \'Did you see any pictures of you here?\' I said...I didn\'t know about that. It would have been very embarrassing. I\'m completely normal-looking, so it was so embarrassing. I didn\'t talk to my mother about this. I gave her the picture and she was embarrassed and then she went away. Then when I got out of that club, I met the other girls at a restaurant. I was there for about ten minutes. We were in love and I\'m so sad for everyone, but there was a good smile on my face. We were talking afterwards, and I said, \'The world needs to be changed. We need to change. There are no parents\' rules or anything, because it\'s impossible for kids of the same age to enjoy life together." The group\'s initial meeting in Tokyo was in which they had a group meeting that lasted for 30 minutes. "We made our decisions for the group. Most of us felt we\'d got the message. As soon as we came up with our team, we didn\'t know what to do," says one of the group members. "At first, as you start to speak, the conversation s ...

# %% [markdown]
# ## Data Cleansing

# %%
#There are repeated senetences, we will remove them manually.
bot_kira[0]['generated_text'].split('.')
# Out:
# ['My name is Yoshikage Kira',
#  " I'm 33 years old",
#  ' I have not played for my entire life',
#  " I don't think I am a professional ballplayer, but at the time it was obvious",
#  ' Now I am starting to ask myself, what am I supposed to do? I try to avoid confrontation',
#  " When I play the game, I always say, 'Ouch",
#  "' I get no help from people and I get no support from people who are very well-known people",
#  ' At least after a while there will be a place called this place and I will always be the one who gets to understand me',
#  " At that moment, I go to the other place and I say to myself, 'This person has made a fool of myself",
#  "' But I feel that my body just isn't ready for that kind of situation",
#  " I go to a place near my house and look around my house and I see all kinds of things that don't make sense",
#  " Those things aren't why I go to this place",
#  " Why I don't go to others places as I'm very concerned about my life",
#  " Why do people think I'm so good, that I'm useless? Why do you think I'm so lucky? I want to prove that I'm still great so that they wouldn't have made a fool of themselves",
#  ' But at the end of the day, this is just a way to make a name for myself',
#  ' I want everyone to respect me for what I do',
#  '" The first person who told me about his story was a member of the Shinigami Family for Girls, the idol group which played and trained her',
#  ' "I remember a time when I played the first day of school," she said, "and everyone was playing at the same time',
#  ' On the first day, everyone were at the same spot',
#  ' As soon as you started playing with me',
#  '',
#  '',
#  'the idol group started a chant and I could hear about their chanting and I took it to be as well',
#  " So I was like, 'We get to watch you play in the morning'",
#  ' So we did and everything went well',
#  '" Yoshikage Kira\'s "liked, disliked" conversation with the other girls who were nearby started a day long conversation that lasted for five minutes, and I have no recollection of the conversation',
#  ' My understanding of what was going on was not quite right',
#  ' On the day that I started the first day of school, I thought about how great that I had done so far',
#  ' This would be the first time my parents would do something like this again',
#  ' You know, even before my parents, my grandfather passed away and I was just very old',
#  " I don't remember feeling any different for a long time",
#  ' In the end I have no idea what the future holds for me, for my life, especially the future part of it',
#  " I don't get to show my affection to anybody, especially the children, but I love them",
#  ' I want them to have one thing in common with me, which is that I am my own person',
#  " I don't care more about the way the world is with me",
#  ' I want to be loved and to be respected and to be respected is what I have done in life',
#  ' "I wish I would never tell a mother to be ashamed," Yoshikage Kira said',
#  ' "All of a sudden I have an older brother, and the younger brother said that to me about me: \'I was in the club when I was 15 years old',
#  "' She said to me, 'Did you see any pictures of you here?' I said",
#  '',
#  '',
#  "I didn't know about that",
#  ' It would have been very embarrassing',
#  " I'm completely normal-looking, so it was so embarrassing",
#  " I didn't talk to my mother about this",
#  ' I gave her the picture and she was embarrassed and then she went away',
#  ' Then when I got out of that club, I met the other girls at a restaurant',
#  ' I was there for about ten minutes',
#  " We were in love and I'm so sad for everyone, but there was a good smile on my face",
#  " We were talking afterwards, and I said, 'The world needs to be changed",
#  ' We need to change',
#  " There are no parents' rules or anything, because it's impossible for kids of the same age to enjoy life together",
#  '" The group\'s initial meeting in Tokyo was in which they had a group meeting that lasted for 30 minutes',
#  ' "We made our decisions for the group',
#  " Most of us felt we'd got the message",
#  ' As soon as we came up with our team, we didn\'t know what to do," says one of the group members',
#  ' "At first, as you start to speak, the conversation started moving off the topic',
#  ' This was surprising',
#  ' We were not confident because even though we were very young, they just thought we were very young',
#  '" At first he thought the group members were having']

# %% [markdown]
# The repetition might be due to the length of sequence of the model.

# %%
#Locate the index of the end of the first completed fake text
for i,s in enumerate(bot_kira[0]['generated_text'].split('.')):
  if 'My name is Yoshikage Kira' in s:
    print(i)
# Out:
# 0

# %%
#bot_kir: A list of sentences of GPT-2 created Kira's self-introduction
bot_kira = bot_kira[0]['generated_text'].split('.')[:24]
bot_kira
# Out:
# ['My name is Yoshikage Kira',
#  " I'm 33 years old",
#  ' I have not played for my entire life',
#  " I don't think I am a professional ballplayer, but at the time it was obvious",
#  ' Now I am starting to ask myself, what am I supposed to do? I try to avoid confrontation',
#  " When I play the game, I always say, 'Ouch",
#  "' I get no help from people and I get no support from people who are very well-known people",
#  ' At least after a while there will be a place called this place and I will always be the one who gets to understand me',
#  " At that moment, I go to the other place and I say to myself, 'This person has made a fool of myself",
#  "' But I feel that my body just isn't ready for that kind of situation",
#  " I go to a place near my house and look around my house and I see all kinds of things that don't make sense",
#  " Those things aren't why I go to this place",
#  " Why I don't go to others places as I'm very concerned about my life",
#  " Why do people think I'm so good, that I'm useless? Why do you think I'm so lucky? I want to prove that I'm still great so that they wouldn't have made a fool of themselves",
#  ' But at the end of the day, this is just a way to make a name for myself',
#  ' I want everyone to respect me for what I do',
#  '" The first person who told me about his story was a member of the Shinigami Family for Girls, the idol group which played and trained her',
#  ' "I remember a time when I played the first day of school," she said, "and everyone was playing at the same time',
#  ' On the first day, everyone were at the same spot',
#  ' As soon as you started playing with me',
#  '',
#  '',
#  'the idol group started a chant and I could hear about their chanting and I took it to be as well',
#  " So I was like, 'We get to watch you play in the morning'"]

# %%
#kira: A list of sentences of Kira's self-introduction in JJBA Part IV
kira = clean.split('.')
kira
# Out:
# ['My name is Yoshikage Kira',
#  " I'm 33 years old",
#  ' My house is in the northeast section of Morioh, where all the villas are, and I am not married',
#  ' I work as an employee for the Kame Yu department stores, and I get home every day by 8 PM at the latest',
#  " I don't smoke, but I occasionally drink",
#  " I'm in bed by 11 PM, and make sure I get eight hours of sleep, no matter what",
#  ' After having a glass of warm milk and doing about twenty minutes of stretches before going to bed, I usually have no problems sleeping until morning',
#  ' Just like a baby, I wake up without any fatigue or stress in the morning',
#  ' I was told there were no issues at my last check-up',
#  " I'm trying to explain that I'm a person who wishes to live a very quiet life",
#  ' I take care not to trouble myself with any enemies, like winning and losing, that would cause me to lose sleep at night',
#  ' That is how I deal with society, and I know that is what brings me happiness',
#  " Although, if I were to fight I wouldn't lose to anyone",
#  '']

# %% [markdown]
# # Sentiment Analysis

# %%
#Analyze each sentence and accumulate the probability and output of each sentence
def sentiment_analysis(text_ls):
    analyzer = SentimentAnalyzer(lang="en") #Define anlayzer
    text_ls = []
    for sent in tqdm(bot_kira):
      tmp = analyzer.predict(sent)
      probas = [] #Store all the probablities
      for p in tmp.probas:
          probas.append(tmp.probas[p])
      text_ls.append([tmp.output]+probas)
    text_ls = pd.DataFrame(text_ls,columns = ['output','NEU','POS','NEG'])
    return text_ls

# %%
sentiment_bot_kira = sentiment_analysis(bot_kira)
sentiment_kira = sentiment_analysis(kira)

# %%
display(sentiment_bot_kira.head())
display(sentiment_kira.head())
# Out:
#   output       NEU       POS       NEG
# 0    NEU  0.000183  0.960661  0.039156
# 1    NEU  0.000473  0.995913  0.003614
# 2    NEG  0.575407  0.422560  0.002034
# 3    NEU  0.026099  0.971858  0.002043
# 4    NEU  0.141897  0.856078  0.002026
#   output       NEU       POS       NEG
# 0    NEU  0.000183  0.960661  0.039156
# 1    NEU  0.000473  0.995913  0.003614
# 2    NEG  0.575407  0.422560  0.002034
# 3    NEU  0.026099  0.971858  0.002043
# 4    NEU  0.141897  0.856078  0.002026

# %%
#Count the number of positve, neutral and negative feelings
output_bot_kira = sentiment_bot_kira.value_counts('output')
output_kira = sentiment_kira.value_counts('output')
print(output_bot_kira)
output_kira
# Out:
# output
# NEU    13
# NEG     7
# POS     4
# dtype: int64
# output
# NEU    13
# NEG     7
# POS     4
# dtype: int64

# %%
#The average of all probabilites of feelings
probas_bot_kira = sentiment_bot_kira[['NEU','POS','NEG']].mean()
probas_kira = sentiment_kira[['NEU','POS','NEG']].mean()
display(probas_bot_kira)
probas_kira
# Out:
# NEU    0.282629
# POS    0.577034
# NEG    0.140337
# dtype: float64
# NEU    0.282629
# POS    0.577034
# NEG    0.140337
# dtype: float64

# %% [markdown]
# The outputs of feelings and probability distribution are identical. Perhaps, Youshikage Kira knows the *universal standard* when introducing yourself or telling a story. Other sentiment anlyzer needs to be investigated for further studies. Frankly speaking, the analyzer generates different results each time, but the same outputs for two texts and thus the credibilty of the analyzer is relatively low.

# %% [markdown]
# # Emotion Analysis

# %%
#Define analyzer
emotion_analyzer = EmotionAnalyzer(lang="en")
emotion_analyzer.predict('Give me a break.') # Verified by Jotaro Kujo, 'Yare Yare daze'
# Out:
# EmotionOutput(output=anger, probas={anger: 0.840, disgust: 0.080, surprise: 0.034, others: 0.013, sadness: 0.013, fear: 0.012, joy: 0.007})

# %%
#Analyze each sentence and accumulate the probability and output of each sentence
def emotion_analysis(text_ls):
    text_ls = []
    for sent in tqdm(bot_kira):
      tmp = emotion_analyzer.predict(sent)
      probas = [] #Store all the probablities
      category = []
      for p in tmp.probas:
          category.append(p)
          probas.append(tmp.probas[p])
      text_ls.append([tmp.output]+probas)
    text_ls = pd.DataFrame(text_ls,columns = ['output']+category)
    return text_ls

# %%
emotion_bot_kira = emotion_analysis(bot_kira)
emotion_kira = emotion_analysis(kira)
display(emotion_bot_kira.head())
display(emotion_kira.head())
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   after removing the cwd from sys.path.
# HBox(children=(FloatProgress(value=0.0, max=24.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=24.0), HTML(value='')))
#    output    others       joy   sadness     anger  surprise   disgust      fear
# 0  others  0.711534  0.196835  0.015948  0.009236  0.020097  0.024335  0.022015
# 1  others  0.720775  0.128574  0.047892  0.008873  0.030038  0.031461  0.032387
# 2  others  0.701091  0.061452  0.094647  0.008471  0.038413  0.049937  0.045989
# 3  others  0.796648  0.039671  0.021320  0.007248  0.029344  0.084180  0.021589
# 4    fear  0.293880  0.016572  0.042061  0.021767  0.071272  0.046595  0.507852
#    output    others       joy   sadness     anger  surprise   disgust      fear
# 0  others  0.711534  0.196835  0.015948  0.009236  0.020097  0.024335  0.022015
# 1  others  0.720775  0.128574  0.047892  0.008873  0.030038  0.031461  0.032387
# 2  others  0.701091  0.061452  0.094647  0.008471  0.038413  0.049937  0.045989
# 3  others  0.796648  0.039671  0.021320  0.007248  0.029344  0.084180  0.021589
# 4    fear  0.293880  0.016572  0.042061  0.021767  0.071272  0.046595  0.507852

# %%
def output_count(df,title):
  sns.set_theme(style="whitegrid")#Set color theme
  df = df.value_counts('output').reset_index()
  df.columns = ['emotion','counts']
  sns.barplot(x='emotion',y='counts',data=df)
  plt.title('Emotion Distribution'+title)
  plt.show()

# %%
output_count(emotion_bot_kira,'Bot_Generated')
output_count(emotion_kira,'Original')

# %% [markdown]
# According to the statistics, we can see the original speech of Kira is mostly classified as others, followed by fear, disgust and sadness. If we consider the scene was about Kira's first time to face a stand user, the results did support the emotion of the script, *the fear of not living a quiet life*. If there are any tools to analyze the tone of voice actor, we may analyze better in the sentiment analysis.

# %% [markdown]
# # Word Embedding

# %%
# !wget https://nlp.stanford.edu/data/glove.6B.zip
# Out:
# --2021-06-17 07:20:23--  https://nlp.stanford.edu/data/glove.6B.zip
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: http://downloads.cs.stanford.edu/nlp/data/glove.6B.zip [following]
# --2021-06-17 07:20:23--  http://downloads.cs.stanford.edu/nlp/data/glove.6B.zip
# Resolving downloads.cs.stanford.edu (downloads.cs.stanford.edu)... 171.64.64.22
# Connecting to downloads.cs.stanford.edu (downloads.cs.stanford.edu)|171.64.64.22|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 862182613 (822M) [application/zip]
# Saving to: ‘glove.6B.zip.1’
#
# glove.6B.zip.1        7%[>                   ]  61.49M  7.85MB/s    eta 97s    ^C

# %%
# !unzip glove.6B.zip
# Out:
# Archive:  glove.6B.zip
# replace glove.6B.50d.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
#GloVe tutorial
embeddings_dict = {}
with open("glove.6B.50d.txt", 'r', encoding='utf-8') as f:
    for line in f:
        values = line.split()
        token = values[0]
        vector = np.asarray(values[1:], "float32")
        embeddings_dict[token] = vector

# %%
def find_closest_embeddings(embedding, cutoff=25):
    return sorted(embeddings_dict.keys(), key=lambda token: spatial.distance.euclidean(embeddings_dict[token], embedding))

# %%
#Visualize original tokens in dictionary
tsne = TSNE(n_components=2, random_state=0)

tokens = list(embeddings_dict.keys())
vectors = [embeddings_dict[token] for token in tokens]

Y = tsne.fit_transform(vectors[:200])

# %%
plt.figure(figsize=(10,10))
plt.scatter(Y[:, 0], Y[:, 1])
for label, x, y in zip(tokens, Y[:, 0], Y[:, 1]):
    plt.annotate(label, xy=(x, y), xytext=(0, 0), textcoords='offset points')
plt.show()

# %%
nltk.download('punkt')
nltk.download('wordnet')
lemmatizer = WordNetLemmatizer()
tokenizer = WordPunctTokenizer()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
def decontracted(text_ls):
    phrase = ' '.join(text_ls)
    # specific
    phrase = re.sub(r"won['’‘`]t", "will not", phrase)
    phrase = re.sub(r"can['’‘`]t", "can not", phrase)
    phrase = re.sub(r"ain['’‘`]t", "am not", phrase)

    # general
    phrase = re.sub(r"n['’‘`]t", " not", phrase)
    phrase = re.sub(r"['’‘`]re", " are", phrase)
    phrase = re.sub(r"['’‘`]s", " is", phrase)
    phrase = re.sub(r"['’‘`]d", " would", phrase)
    phrase = re.sub(r"['’‘`]ll", " will", phrase)
    phrase = re.sub(r"['’‘`]t", " not", phrase)
    phrase = re.sub(r"['’‘`]ve", " have", phrase)
    phrase = re.sub(r"['’‘`]m", " am", phrase)

    #phrase = re.sub('([.;!?])', r' \1 ', phrase)
    phrase = re.sub(r'[^\w.?!;]', ' ', phrase)
    phrase = re.sub(' +', ' ', phrase)
    sentences = re.split('([.;!?] *)', phrase)
    sentences = [lemmatizer.lemmatize(i.lower()) for i in  sentences]
    return ' '.join(sentences)

# %%
text_kira = decontracted(kira)
bot_text_kira = decontracted(bot_kira)
text_kira[:10]
# Out:
# 'my name is'

# %%
bot_text_kira
# Out:
# 'my name is yoshikage kira i am 33 years old i have not played for my entire life i do not think i am a professional ballplayer but at the time it was obvious now i am starting to ask myself what am i supposed to do ?  i try to avoid confrontation when i play the game i always say ouch i get no help from people and i get no support from people who are very well known people at least after a while there will be a place called this place and i will always be the one who gets to understand me at that moment i go to the other place and i say to myself this person has made a fool of myself but i feel that my body just is not ready for that kind of situation i go to a place near my house and look around my house and i see all kinds of things that do not make sense those things are not why i go to this place why i do not go to others places as i am very concerned about my life why do people think i am so good that i am useless ?  why do you think i am so lucky ?  i want to prove that i am still great so that they would not have made a fool of themselves but at the end of the day this is just a way to make a name for myself i want everyone to respect me for what i do the first person who told me about his story was a member of the shinigami family for girls the idol group which played and trained her i remember a time when i played the first day of school she said and everyone was playing at the same time on the first day everyone were at the same spot as soon as you started playing with me the idol group started a chant and i could hear about their chanting and i took it to be as well so i was like we get to watch you play in the morning '

# %%
def visualize_tokens(text):
  tokens = tokenizer.tokenize(text)

  plt.figure(figsize=(10,10))
  #Visualize tokens in dictionary
  tsne = TSNE(n_components=2, random_state=0)
  vectors = []
  vocab = []
  for token in set(tokens): #Use set to maintain unique word
    try :  #Prevent the word does not exists in the embeddings
      arr = embeddings_dict[token]
    except:
      continue
    vocab.append(token)
    vectors.append(arr)

  Y = tsne.fit_transform(vectors[:1000])

  plt.scatter(Y[:, 0], Y[:, 1])
  for label, x, y in zip(vocab, Y[:, 0], Y[:, 1]):
      plt.annotate(label, xy=(x, y), xytext=(0, 0), textcoords='offset points')
  plt.show()
  return token

# %%
token_kira = visualize_tokens(text_kira)
token_bot_kira = visualize_tokens(bot_text_kira)

# %% [markdown]
# From observations, it is found that there is subtle upwards tendency for the word embeddings of Kira's speech while bot speech tends to downwards. **In fact,we are not confident of differentiating using word embeddings graph.**

# %% [markdown]
# # Part1 Conclusion
# Sentiment analysis, emotion analysis and visualization of word embedding are intuitive for human comprehension but not that *significant enough* for bot detection.

# %% [markdown]
# # To be continue...
# *   SVD decomposition
# *   TF-IDF decomposition
# *   KMeans Clustering
# *   PCA Transformation
# *   Machine Translation
